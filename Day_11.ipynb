# %%
filename = "file.txt"

lines = [
    "Python makes file handling super easy!",
    "This is a text file with multiple lines.",
    "Each line contains something different.",
    "You can read, write, or even modify files.",
    "Let's keep learning and practicing Python."
]

with open(filename, 'w') as f:
    for line in lines:
        f.write(line + '\n')

# %% [markdown]
# **1. Write a Python program to count the number of lines in a text file.**

# %%
with open('file.txt', 'r') as f:
  lines = f.readlines()
  no_of_lines = len(lines)
  print("No. of lines in file are:", no_of_lines)
# Out:
# No. of lines in file are: 5

# %% [markdown]
# 2. Write a program to count the total number of words in a given text file.

# %%
with open('file.txt', 'r') as f:
  content = f.read()
  words_count = content.split()
  print("No. of words in file are:", len(words_count))
# Out:
# No. of words in file are: 33

# %% [markdown]
# **3. Write a program that counts the number of characters (including spaces) in a file.**

# %%
with open('file.txt', 'r') as f:
  content = f.read()
  print("No. of words in file are:", len(content))
# Out:
# No. of words in file are: 206

# %% [markdown]
# **4. Write a Python script to search for a specific word in a text file and display the lines where it appears.**

# %%
word = input("Enter the word you want to search: ")
found = True

with open('file.txt', 'r') as f:
  content = f.readlines()
  # line = content.split()
  for line in content:
   if word.lower() in line.lower():
      print(line)

if not found:
  print("Word not found")
# Out:
# Enter the word you want to search: p
# Python makes file handling super easy!
#
# This is a text file with multiple lines.
#
# Let's keep learning and practicing Python.

# %% [markdown]
# **5. Create a program that replaces a given word in a file with another word and saves the result.**

# %%
with open('file.txt', 'r') as f:
  content = f.read()

replace_word = input("Enter the word you want to replace: ")
replace_with = input("Enter the word you want to replace with: ")
new_content = content.replace(replace_word, replace_with)

with open('file.txt', 'w') as f:
  f.write(new_content)
# Out:
# Enter the word you want to replace: or
# Enter the word you want to replace with: and

# %% [markdown]
# **6. Write a program to read a file and print the frequency of each word (word count).**

# %%
with open('file.txt', 'r') as f:
  content = f.read()
  content = content.lower()
  word_count = content.split()
word_freq = {}

for words in word_count:
  if words in word_freq:
    word_freq[words] += 1
  else:
    word_freq[words] = 1

for i, count in word_freq.items():
 print(f"{i} : {count}")
# Out:
# python : 1
# makes : 1
# file : 2
# handling : 1
# super : 1
# easy! : 1
# this : 1
# is : 1
# a : 1
# text : 1
# with : 1
# multiple : 1
# lines. : 1
# each : 1
# line : 1
# contains : 1
# something : 1
# different. : 1
# you : 1
# can : 1
# read, : 1
# write, : 1
# and : 2
# even : 1
# modify : 1
# files. : 1
# let's : 1
# keep : 1
# learning : 1
# practicing : 1
# python. : 1

# %% [markdown]
# **7. Write a script to read a file and count how many times a specific word appears.**

# %%
word_appear = input("Enter the word: ")
count = 0

with open('file.txt', 'r') as f:
  content = f.read()

word = content.lower()
count_word = word.count(word_appear.lower())

print(f"The word {word_appear} appears {count_word} times in the file.")
# Out:
# Enter the word: is
# The word is appears 2 times in the file.

# %% [markdown]
# **8. Write a program that removes all punctuation from a text file and saves the cleaned version.**

# %%
import string

with open('file.txt', 'r') as f:
  content = f.read()

for p in string.punctuation:
  clean_context = content.replace(p, '')

with open('file.txt', 'w') as f:
  f.write(clean_context)

# %% [markdown]
# **9. Write a Python program to reverse the content of each line in a file.**

# %%
with open('file.txt', 'r') as f:
  lines = f.readlines()


with open('file.txt', 'w') as f1:
  for line in lines:
    reversed_line = line.srip()[::-1]
    f1.write(reversed_line + '\n')

# %% [markdown]
# **10. Write a program to copy the contents of one file to another.**

# %%
with open('file.txt', 'r') as f1:
  content = f1.read()

with open('file2.txt', 'w') as f2:
  f2.write(content)

print("Content copied sucessfully!")
# Out:
# Content copied sucessfully!

# %% [markdown]
# **11. Write a script that appends a new line to an existing file.**

# %%
with open('file.txt', 'a') as f:
 f.write("\nLearning Python is fun")

# %% [markdown]
# **12. Write a program to find and replace multiple words in a text file using a dictionary.**

# %%
replace = {
    "python" : "java" ,
    "or" : "and"
}

with open('file.txt', 'r') as f:
  content = f.read()

for i, j in replace.items():
  content = content.replace(i, j)

with open('file.txt', 'w') as f:
  f.write(content)

# %% [markdown]
# **13. Write a program that reads a file and prints only the unique words used in it.**

# %%
import string
with open('file.txt', 'r') as f:
  content = f.read()

for p in string.punctuation:
  content = content.replace(p, '')

words = content.lower().split()
unique_word = set(words)
print(unique_word)
# Out:
# {'python', 'is', 'fun', 'learning'}

# %% [markdown]
# **14. Write a Python script to read a text file and print its content in uppercase.**

# %%
with open('file.txt', 'r') as f:
  content = f.read()
  print(content.upper())
# Out:
# LEARNING PYTHON IS FUN

# %%
with open('file.txt', 'w') as f:
    f.write("""Python makes file handling super easy! \n
This is a text file with multiple lines. \n
Each line contains something different. \n
Let's keep learning and practicing Python. \n""")

# %% [markdown]
# **15. Write a program to read a file and remove all duplicate lines.**

# %%
with open('file.txt', 'r') as f:
  content = f.readlines()

unique_lines = []

for line in content:
  if line not in unique_lines:
    unique_lines.append(line)

with open('file.txt', 'w') as f:
  f.writelines(unique_lines)
