# %% [markdown]
# **1. Create a class named 'Student' with attributes name and age. Instantiate two objects and print their details.**

# %%
class Student:
  def __init__(self, n, a):
    self.name = n
    self.age = a

  def details(self):
    print(f"Your name is {self.name} and you are {self.age} years old")

s1 = Student("Nimra", 20)
s2 = Student("Areeba", 19)

s1.details()
s2.details()
# Out:
# Your name is Nimra and you are 20 years old
# Your name is Areeba and you are 19 years old

# %% [markdown]
# **2. Define a class 'Car' with an __init__ method that initializes brand, model, and year.**

# %%
class Car:
  def __init__(self, b, m, y):
    self.brand = b
    self.model = m
    self.year = y

  def detail(self):
    print(f"The car is of {self.brand} brand, {self.model} model and {self.year} year")

c1 = Car("Toyota", "Corolla", 2022)
c2 = Car("Honda", "Civic", 2021)

c1.detail()
c2.detail()
# Out:
# The car is of Toyota brand, Corolla model and 2022 year
# The car is of Honda brand, Civic model and 2021 year

# %% [markdown]
# **3. Write a class 'Circle' that takes radius as a parameter and calculates area and circumference.**

# %%
import math

class Circle:
  def __init__(self, r):
    self.radius = r

  def cal(self):
    area = math.pi * (self.radius * self.radius)
    circumference = 2 * math.pi * self.radius
    print(f"The area of circle is {area} and circumference is {circumference:}")


r = float(input("Enter radius of circle: "))

c = Circle(r)
c.cal()
# Out:
# Enter radius of circle: 5
# The area of circle is 78.53981633974483 and circumference is 31.41592653589793

# %% [markdown]
# **4. Create a class 'Employee' with a method to display employee details.**

# %%
class Employee:
  def __init__(self, n, d, s):
    self.name = n
    self.department = d
    self.salary = s

  def details(self):
    print(f"Your name is {self.name} and you are in {self.department} and your salary is {self.salary}")

e1 = Employee("Nimra", "Finance", 150000)
e2 = Employee("Areeba", "HR", 100000)

e1.details()
e2.details()
# Out:
# Your name is Nimra and you are in Finance and your salary is 150000
# Your name is Areeba and you are in HR and your salary is 100000

# %% [markdown]
# **5. Implement a class 'Book' to store book title, author and price. Add a method to show details.**

# %%
class Book:
  def __init__(self, t, a, p):
    self.title = t
    self.author = a
    self.price = p

  def details(self):
    print(f"Book title is {self.title} and its author is {self.author} and price is {self.price}")

b1 = Book("'Python Crash Course'", "Eric Matthes", 3000)
b2 = Book("'Automate the boring stuff with Python'", "AI sweigart", 2500)

b1.details()
b2.details()
# Out:
# Book title is 'Python Crash Course' and its author is Eric Matthes and price is 3000
# Book title is 'Automate the boring stuff with Python' and its author is AI sweigart and price is 2500

# %% [markdown]
# **6. Design a class 'Calculator' with methods to add, subtract, multiply and divide two numbers.**

# %%
class Calculator:

  def add(self, n1, n2):
   return n1 + n2

  def subtract(self, n1, n2):
   return n1 - n2

  def multiply(self, n1, n2):
   return n1 * n2

  def divide(self, n1, n2):
    if n2 == 0:
      return "Cannot divide to zero"
    else:
      return n1 / n2


n1 = int(input("Enter first number: "))
n2 = int(input("Enter second number: "))

c = Calculator()
print("Addition: ",c.add(n1, n2))
print("Subtraction: ",c.subtract(n1, n2))
print("Multiplication: ",c.multiply(n1, n2))
print("Division: ",c.divide(n1, n2))
# Out:
# Enter first number: 6
# Enter second number: 2
# Addition:  8
# Subtraction:  4
# Multiplication:  12
# Division:  3.0

# %% [markdown]
# **7. Create a class 'BankAccount' with deposit and withdraw methods and display current balance.**

# %%
class BankAccount:
    def __init__(self, initial_balance = 0):
        self.balance = initial_balance

    def deposit(self, amount):
      self.balance += amount

    def withdraw(self, amount):
      if self.balance >= amount:
        self.balance -= amount
      else:
        print("Insufficient funds")

    def get_balance(self):
      return self.balance
      print("Your Balance is:", self.balance)

b = BankAccount(1000)
b.deposit(500)
b.withdraw(200)
print("Your Balance is:", b.get_balance())
# Out:
# Your Balance is: 1300

# %% [markdown]
# **8. Define a class 'Rectangle' with width and height. Add a method to calculate area and perimeter.**

# %%
class Rectangle:
    def __init__(self, l, w):
        self.length = l
        self.width = w

    def area(self):
        return self.length * self.width

    def perimeter(self):
      return 2 * (self.length + self.width)

l = float(input("Enter length of rectangle: "))
w = float(input("Enter width of rectangle: "))

r = Rectangle(l, w)
print("Area of rectangle is:", r.area())
print("Perimeter of rectangle is:", r.perimeter())
# Out:
# Enter length of rectangle: 5
# Enter width of rectangle: 3
# Area of rectangle is: 15.0
# Perimeter of rectangle is: 16.0

# %% [markdown]
# **9. Write a class 'Person' with a greeting method and test it with different names.**

# %%
class Person:
  def __init__(self, n):
    self.name = n

  def greet(self):
    print(f"Hey, I am {self.name}")

s1 = Person("Nimra")
s2 = Person("Areeba")

s1.greet()
s2.greet()
# Out:
# Hey, I am Nimra
# Hey, I am Areeba

# %% [markdown]
# **10. Make a class 'Laptop' with attributes brand, RAM, and processor. Display them using a method.**

# %%
class Laptop:
    def __init__(self, brand, ram, processor):
        self.brand = brand
        self.ram = ram
        self.processor = processor

    def detail(self):
        print(f"Laptop: {self.brand} \n RAM: {self.ram} \n Processor: {self.processor}")

l = Laptop("HP", "8GB", "Intel Core i5")
l.detail()
# Out:
# Laptop: HP
#  RAM: 8GB
#  Processor: Intel Core i5

# %% [markdown]
# **11. Create a base class 'Animal' and derived classes 'Dog' and 'Cat'. Demonstrate inheritance.**

# %%
class Animal:
  def speak(self):
    print("Animals make sounds")

class Cat(Animal):
  def sound(self):
   print("Cat Meows")

class Dog(Animal):
  def so(self):
   print("Dog barks")

c = Cat()
d = Dog()
c.speak()
d.speak()
# Out:
# Animals make sounds
# Animals make sounds

# %% [markdown]
# **12. Implement method overriding in a class hierarchy involving 'Shape' -> 'Square' and 'Circle'.**

# %%
class One:
  def s(self):
    print("Shape")

class Two(One):
  def s(self):
   print("Square")

class Three(One):
  def s(self):
   print("Circle")

t = Two()
th = Three()
t.s()
th.s()
# Out:
# Square
# Circle

# %% [markdown]
# **13. Write a program to demonstrate polymorphism using a base class 'Vehicle' and derived classes.**

# %%
class Vehicle:
  def start(self):
    print("Vehicle started")

class Car(Vehicle):
  def start(self):
    print("Car started")

class Bike(Vehicle):
  def start(self):
    print("Bike started")

c = Car()
b = Bike()
c.start()
b.start()
# Out:
# Car started
# Bike started

# %% [markdown]
# **14. Use abstract base class 'Payment' with abstract method 'pay'. Create subclasses for CardPayment and CashPayment.**

# %%
from abc import ABC, abstractmethod
class Payment:
  @abstractmethod
  def pay(self):
    pass

class CardPayment(Payment):
  def pay(self):
    print("Card Payment")

class CashPayment(Payment):
  def pay(self):
   print("Cash Payment")

cp1 = CardPayment()
cp2 = CashPayment()
cp1.pay()
cp2.pay()
# Out:
# Card Payment
# Cash Payment

# %% [markdown]
# **15. Demonstrate encapsulation by creating a class 'Account' with private attributes and getter/setter methods.**

# %%
class Account:
  def __init__(self, name, balance):
    self.__name = name
    self.__balance = balance

  def get_name(self):
    return self.__name

  def set_balance(self, name):
    self.__name = name

  def get_balance(self):
    return self.__balance

  def set_balance(self, balance):
    self.__balance = balance


a = Account("Nimra", 10000)
a.set_balance(20000)
print(a.get_name())
print(a.get_balance())
# Out:
# Nimra
# 20000
